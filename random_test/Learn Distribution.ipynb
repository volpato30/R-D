# %% [markdown]
# # feed forward NN with one hidden layer

# %%
import os
import sys
import timeit

import numpy

import theano
import theano.tensor as T
from theano.tensor.signal import pool
from theano.tensor.nnet import conv2d
from logistic_sgd import LogisticRegression, load_data
#from mlp import HiddenLayer
# Out:
# Using gpu device 0: TITAN X (Pascal) (CNMeM is disabled, cuDNN 5105)

# %%
class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, activation=T.nnet.relu):
        self.input = input
        self.mu = theano.shared(value = 0.0, name='mu')
        self.sigma_sqr = theano.shared(value = 1.0, name='sigma_sqr')
        sigma = numpy.sqrt(float(self.sigma_sqr.get_value()))
        self.n_in = n_in
        self.n_out = n_out
        temp = rng.normal(float(self.mu.get_value()),sigma,size=(self.n_in, self.n_out))
        W_values = numpy.asarray(temp,dtype=theano.config.floatX)
        self.W = theano.shared(value=W_values, name='W')
        lin_output = T.dot(input, self.W)
        self.output = activation(lin_output)
    def generate_W(self, rng):
        sigma = numpy.sqrt(float(self.sigma_sqr.get_value()))
        temp = rng.normal(float(self.mu.get_value()),sigma,size=(self.n_in, self.n_out))
        W_values = numpy.asarray(temp,dtype=theano.config.floatX)
        self.W.set_value(W_values)

# %%
batch_size = 1000
rng = numpy.random.RandomState(2345)
datasets = load_data('mnist.pkl.gz')
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]
# compute number of minibatches for training, validation and testing
n_train_batches = train_set_x.get_value(borrow=True).shape[0]
n_valid_batches = valid_set_x.get_value(borrow=True).shape[0]
n_test_batches = test_set_x.get_value(borrow=True).shape[0]
n_train_batches //= batch_size
n_valid_batches //= batch_size
n_test_batches //= batch_size
# allocate symbolic variables for the data
index = T.lscalar()  # index to a [mini]batch
# start-snippet-1
x = T.matrix('x')   # the data is presented as rasterized images
y = T.ivector('y')  # the labels are presented as 1D vector of
print('... building the model')
# Out:
# ... loading data
# ... building the model

# %%
layer0_input = x.reshape((batch_size, 784))
layer0 = HiddenLayer(rng,input=layer0_input,n_in = 784,n_out = 500)
layer1 = LogisticRegression(input = layer0.output, n_in=500, n_out=10)
cost = layer1.negative_log_likelihood(y)
learning_rate = 0.01
n_epochs = 200

# %% [markdown]
# # train full param

# %%
test_model = theano.function(
    [index],
    layer1.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model = theano.function(
    [index],
    layer1.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

params = layer1.params + [layer0.W]
grads = T.grad(cost, params)
updates = [
    (param_i, param_i - learning_rate * grad_i)
    for param_i, grad_i in zip(params, grads)
]
train_model = theano.function(
    [index],
    cost,
    updates=updates,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

# %%
validation_frequency = n_train_batches
best_validation_loss = numpy.inf
best_iter = 0
test_score = 0.
start_time = timeit.default_timer()

epoch = 0
done_looping = False

while (epoch < n_epochs) and (not done_looping):
    epoch = epoch + 1
    for minibatch_index in range(n_train_batches):
        iter = (epoch - 1) * n_train_batches + minibatch_index

        if iter % 100 == 0:
            print('training @ iter = ', iter)
        cost_ij = train_model(minibatch_index)

        if (iter + 1) % validation_frequency == 0:

            # compute zero-one loss on validation set
            validation_losses = [validate_model(i) for i
                                 in range(n_valid_batches)]
            this_validation_loss = numpy.mean(validation_losses)
            print('epoch %i, minibatch %i/%i, validation error %f %%' %
                  (epoch, minibatch_index + 1, n_train_batches,
                   this_validation_loss * 100.))

            # if we got the best validation score until now
            if this_validation_loss < best_validation_loss:
                # save best validation score and iteration number
                best_validation_loss = this_validation_loss
                best_iter = iter
                # test it on the test set
                test_losses = [
                    test_model(i)
                    for i in range(n_test_batches)
                ]
                test_score = numpy.mean(test_losses)
                print(('     epoch %i, minibatch %i/%i, test error of '
                       'best model %f %%') %
                      (epoch, minibatch_index + 1, n_train_batches,
                       test_score * 100.))
end_time = timeit.default_timer()
print('Optimization complete.')
print('Best validation score of %f %% obtained at iteration %i, '
      'with test performance %f %%' %
      (best_validation_loss * 100., best_iter + 1, test_score * 100.))
# Out:
# training @ iter =  0
# epoch 1, minibatch 50/50, validation error 6.870000 %
#      epoch 1, minibatch 50/50, test error of best model 7.060000 %
# epoch 2, minibatch 50/50, validation error 6.870000 %
# training @ iter =  100
# epoch 3, minibatch 50/50, validation error 6.870000 %
# epoch 4, minibatch 50/50, validation error 6.840000 %
#      epoch 4, minibatch 50/50, test error of best model 7.000000 %
# training @ iter =  200
# epoch 5, minibatch 50/50, validation error 6.810000 %
#      epoch 5, minibatch 50/50, test error of best model 6.990000 %
# epoch 6, minibatch 50/50, validation error 6.810000 %
# training @ iter =  300
# epoch 7, minibatch 50/50, validation error 6.780000 %
#      epoch 7, minibatch 50/50, test error of best model 6.980000 %
# epoch 8, minibatch 50/50, validation error 6.750000 %
#      epoch 8, minibatch 50/50, test error of best model 6.960000 %
# training @ iter =  400
# epoch 9, minibatch 50/50, validation error 6.750000 %
# epoch 10, minibatch 50/50, validation error 6.740000 %
#      epoch 10, minibatch 50/50, test error of best model 6.930000 %
# training @ iter =  500
# epoch 11, minibatch 50/50, validation error 6.760000 %
# epoch 12, minibatch 50/50, validation error 6.760000 %
# training @ iter =  600
# epoch 13, minibatch 50/50, validation error 6.760000 %
# epoch 14, minibatch 50/50, validation error 6.760000 %
# training @ iter =  700
# epoch 15, minibatch 50/50, validation error 6.750000 %
# epoch 16, minibatch 50/50, validation error 6.730000 %
#      epoch 16, minibatch 50/50, test error of best model 6.850000 %
# training @ iter =  800
# epoch 17, minibatch 50/50, validation error 6.720000 %
#      epoch 17, minibatch 50/50, test error of best model 6.850000 %
# epoch 18, minibatch 50/50, validation error 6.700000 %
#      epoch 18, minibatch 50/50, test error of best model 6.840000 %
# training @ iter =  900
# epoch 19, minibatch 50/50, validation error 6.690000 %
#      epoch 19, minibatch 50/50, test error of best model 6.820000 %
# epoch 20, minibatch 50/50, validation error 6.650000 %
#      epoch 20, minibatch 50/50, test error of best model 6.810000 %
# training @ iter =  1000
# epoch 21, minibatch 50/50, validation error 6.620000 %
#      epoch 21, minibatch 50/50, test error of best model 6.780000 %
# epoch 22, minibatch 50/50, validation error 6.590000 %
#      epoch 22, minibatch 50/50, test error of best model 6.730000 %
# training @ iter =  1100
# epoch 23, minibatch 50/50, validation error 6.540000 %
#      epoch 23, minibatch 50/50, test error of best model 6.730000 %
# epoch 24, minibatch 50/50, validation error 6.540000 %
# training @ iter =  1200
# epoch 25, minibatch 50/50, validation error 6.500000 %
#      epoch 25, minibatch 50/50, test error of best model 6.670000 %
# epoch 26, minibatch 50/50, validation error 6.480000 %
#      epoch 26, minibatch 50/50, test error of best model 6.650000 %
# training @ iter =  1300
# epoch 27, minibatch 50/50, validation error 6.450000 %
#      epoch 27, minibatch 50/50, test error of best model 6.640000 %
# epoch 28, minibatch 50/50, validation error 6.440000 %
#      epoch 28, minibatch 50/50, test error of best model 6.630000 %
# training @ iter =  1400
# epoch 29, minibatch 50/50, validation error 6.410000 %
#      epoch 29, minibatch 50/50, test error of best model 6.630000 %
# epoch 30, minibatch 50/50, validation error 6.390000 %
#      epoch 30, minibatch 50/50, test error of best model 6.630000 %
# training @ iter =  1500
# epoch 31, minibatch 50/50, validation error 6.340000 %
#      epoch 31, minibatch 50/50, test error of best model 6.610000 %
# epoch 32, minibatch 50/50, validation error 6.340000 %
# training @ iter =  1600
# epoch 33, minibatch 50/50, validation error 6.330000 %
#      epoch 33, minibatch 50/50, test error of best model 6.560000 %
# epoch 34, minibatch 50/50, validation error 6.320000 %
#      epoch 34, minibatch 50/50, test error of best model 6.530000 %
# training @ iter =  1700
# epoch 35, minibatch 50/50, validation error 6.300000 %
#      epoch 35, minibatch 50/50, test error of best model 6.520000 %
# epoch 36, minibatch 50/50, validation error 6.270000 %
#      epoch 36, minibatch 50/50, test error of best model 6.500000 %
# training @ iter =  1800
# epoch 37, minibatch 50/50, validation error 6.230000 %
#      epoch 37, minibatch 50/50, test error of best model 6.490000 %
# epoch 38, minibatch 50/50, validation error 6.230000 %
# training @ iter =  1900
# epoch 39, minibatch 50/50, validation error 6.210000 %
#      epoch 39, minibatch 50/50, test error of best model 6.430000 %
# epoch 40, minibatch 50/50, validation error 6.210000 %
# training @ iter =  2000
# epoch 41, minibatch 50/50, validation error 6.210000 %
# epoch 42, minibatch 50/50, validation error 6.190000 %
#      epoch 42, minibatch 50/50, test error of best model 6.440000 %
# training @ iter =  2100
# epoch 43, minibatch 50/50, validation error 6.190000 %
# epoch 44, minibatch 50/50, validation error 6.180000 %
#      epoch 44, minibatch 50/50, test error of best model 6.410000 %
# training @ iter =  2200
# epoch 45, minibatch 50/50, validation error 6.150000 %
#      epoch 45, minibatch 50/50, test error of best model 6.400000 %
# epoch 46, minibatch 50/50, validation error 6.140000 %
#      epoch 46, minibatch 50/50, test error of best model 6.400000 %
# training @ iter =  2300
# epoch 47, minibatch 50/50, validation error 6.130000 %
#      epoch 47, minibatch 50/50, test error of best model 6.390000 %
# epoch 48, minibatch 50/50, validation error 6.110000 %
#      epoch 48, minibatch 50/50, test error of best model 6.380000 %
# training @ iter =  2400
# epoch 49, minibatch 50/50, validation error 6.090000 %
#      epoch 49, minibatch 50/50, test error of best model 6.400000 %
# epoch 50, minibatch 50/50, validation error 6.080000 %
#      epoch 50, minibatch 50/50, test error of best model 6.390000 %
# training @ iter =  2500
# epoch 51, minibatch 50/50, validation error 6.080000 %
# epoch 52, minibatch 50/50, validation error 6.080000 %
# training @ iter =  2600
# epoch 53, minibatch 50/50, validation error 6.070000 %
#      epoch 53, minibatch 50/50, test error of best model 6.350000 %
# epoch 54, minibatch 50/50, validation error 6.060000 %
#      epoch 54, minibatch 50/50, test error of best model 6.340000 %
# training @ iter =  2700
# epoch 55, minibatch 50/50, validation error 6.060000 %
# epoch 56, minibatch 50/50, validation error 6.020000 %
#      epoch 56, minibatch 50/50, test error of best model 6.330000 %
# training @ iter =  2800
# epoch 57, minibatch 50/50, validation error 6.000000 %
#      epoch 57, minibatch 50/50, test error of best model 6.320000 %
# epoch 58, minibatch 50/50, validation error 5.970000 %
#      epoch 58, minibatch 50/50, test error of best model 6.300000 %
# training @ iter =  2900
# epoch 59, minibatch 50/50, validation error 5.970000 %
# epoch 60, minibatch 50/50, validation error 5.950000 %
#      epoch 60, minibatch 50/50, test error of best model 6.240000 %
# training @ iter =  3000
# epoch 61, minibatch 50/50, validation error 5.900000 %
#      epoch 61, minibatch 50/50, test error of best model 6.220000 %
# epoch 62, minibatch 50/50, validation error 5.900000 %
# training @ iter =  3100
# epoch 63, minibatch 50/50, validation error 5.890000 %
#      epoch 63, minibatch 50/50, test error of best model 6.170000 %
# epoch 64, minibatch 50/50, validation error 5.880000 %
#      epoch 64, minibatch 50/50, test error of best model 6.150000 %
# training @ iter =  3200
# epoch 65, minibatch 50/50, validation error 5.870000 %
#      epoch 65, minibatch 50/50, test error of best model 6.140000 %
# epoch 66, minibatch 50/50, validation error 5.880000 %
# training @ iter =  3300
# epoch 67, minibatch 50/50, validation error 5.850000 %
#      epoch 67, minibatch 50/50, test error of best model 6.110000 %
# epoch 68, minibatch 50/50, validation error 5.840000 %
#      epoch 68, minibatch 50/50, test error of best model 6.100000 %
# training @ iter =  3400
# epoch 69, minibatch 50/50, validation error 5.830000 %
#      epoch 69, minibatch 50/50, test error of best model 6.100000 %
# epoch 70, minibatch 50/50, validation error 5.830000 %
# training @ iter =  3500
# epoch 71, minibatch 50/50, validation error 5.800000 %
#      epoch 71, minibatch 50/50, test error of best model 6.090000 %
# epoch 72, minibatch 50/50, validation error 5.790000 %
#      epoch 72, minibatch 50/50, test error of best model 6.080000 %
# training @ iter =  3600
# epoch 73, minibatch 50/50, validation error 5.780000 %
#      epoch 73, minibatch 50/50, test error of best model 6.070000 %
# epoch 74, minibatch 50/50, validation error 5.760000 %
#      epoch 74, minibatch 50/50, test error of best model 6.060000 %
# training @ iter =  3700
# epoch 75, minibatch 50/50, validation error 5.730000 %
#      epoch 75, minibatch 50/50, test error of best model 6.050000 %
# epoch 76, minibatch 50/50, validation error 5.730000 %
# training @ iter =  3800
# epoch 77, minibatch 50/50, validation error 5.720000 %
#      epoch 77, minibatch 50/50, test error of best model 6.010000 %
# epoch 78, minibatch 50/50, validation error 5.680000 %
#      epoch 78, minibatch 50/50, test error of best model 6.000000 %
# training @ iter =  3900
# epoch 79, minibatch 50/50, validation error 5.660000 %
#      epoch 79, minibatch 50/50, test error of best model 5.970000 %
# epoch 80, minibatch 50/50, validation error 5.650000 %
#      epoch 80, minibatch 50/50, test error of best model 5.950000 %
# training @ iter =  4000
# epoch 81, minibatch 50/50, validation error 5.620000 %
#      epoch 81, minibatch 50/50, test error of best model 5.920000 %
# epoch 82, minibatch 50/50, validation error 5.600000 %
#      epoch 82, minibatch 50/50, test error of best model 5.900000 %
# training @ iter =  4100
# epoch 83, minibatch 50/50, validation error 5.550000 %
#      epoch 83, minibatch 50/50, test error of best model 5.900000 %
# epoch 84, minibatch 50/50, validation error 5.550000 %
# training @ iter =  4200
# epoch 85, minibatch 50/50, validation error 5.550000 %
# epoch 86, minibatch 50/50, validation error 5.530000 %
#      epoch 86, minibatch 50/50, test error of best model 5.860000 %
# training @ iter =  4300
# epoch 87, minibatch 50/50, validation error 5.530000 %
# epoch 88, minibatch 50/50, validation error 5.520000 %
#      epoch 88, minibatch 50/50, test error of best model 5.800000 %
# training @ iter =  4400
# epoch 89, minibatch 50/50, validation error 5.520000 %
# epoch 90, minibatch 50/50, validation error 5.500000 %
#      epoch 90, minibatch 50/50, test error of best model 5.770000 %
# training @ iter =  4500
# epoch 91, minibatch 50/50, validation error 5.450000 %
#      epoch 91, minibatch 50/50, test error of best model 5.770000 %
# epoch 92, minibatch 50/50, validation error 5.430000 %
#      epoch 92, minibatch 50/50, test error of best model 5.750000 %
# training @ iter =  4600
# epoch 93, minibatch 50/50, validation error 5.420000 %
#      epoch 93, minibatch 50/50, test error of best model 5.730000 %
# epoch 94, minibatch 50/50, validation error 5.390000 %
#      epoch 94, minibatch 50/50, test error of best model 5.730000 %
# training @ iter =  4700
# epoch 95, minibatch 50/50, validation error 5.390000 %
# epoch 96, minibatch 50/50, validation error 5.380000 %
#      epoch 96, minibatch 50/50, test error of best model 5.700000 %
# training @ iter =  4800
# epoch 97, minibatch 50/50, validation error 5.380000 %
# epoch 98, minibatch 50/50, validation error 5.370000 %
#      epoch 98, minibatch 50/50, test error of best model 5.690000 %
# training @ iter =  4900
# epoch 99, minibatch 50/50, validation error 5.360000 %
#      epoch 99, minibatch 50/50, test error of best model 5.680000 %
# epoch 100, minibatch 50/50, validation error 5.360000 %
# Optimization complete.
# Best validation score of 5.360000 % obtained at iteration 4950, with test performance 5.680000 %

# %% [markdown]
# # train distribution of the hidden layer
# ## distribution param update:
# mu_new = mu_old - lr \* mean(grad(cost,W))
#
# sigma_sqr_new = sigma_sqr_old - lr \* (mean(grad(cost,W^2)-1/2/mu \* mean(grad(cost,W)))

# %%
layer0_input = x.reshape((batch_size, 784))
layer0 = HiddenLayer(rng,input=layer0_input,n_in = 784,n_out = 500)
layer1 = LogisticRegression(input = layer0.output, n_in=500, n_out=10)
cost = layer1.negative_log_likelihood(y)
learning_rate = 0.01
n_epochs = 200
test_model = theano.function(
    [index],
    layer1.errors(y),
    givens={
        x: test_set_x[index * batch_size: (index + 1) * batch_size],
        y: test_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

validate_model = theano.function(
    [index],
    layer1.errors(y),
    givens={
        x: valid_set_x[index * batch_size: (index + 1) * batch_size],
        y: valid_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

params = layer1.params
grads = T.grad(cost, params)
updates = [
    (param_i, param_i - learning_rate * grad_i)
    for param_i, grad_i in zip(params, grads)
]

grads_hidden_w = T.grad(cost, layer0.W) 
updates.append((layer0.mu, layer0.mu - learning_rate * T.mean(grads_hidden_w)))
# method of moments estimate of sigma_sqr:
# sigma_sqr_hat = T.mean(T.sqr(layer0.W)) - T.sqr(T.mean(layer0.W))
# compute the gradient cost wrt sigma_sqr_hat manually:

grad_sigma_sqr_hat = T.mean(grads_hidden_w/layer0.W/2)-T.mean(grads_hidden_w)/T.mean(layer0.W)/2

updates.append(( layer0.sigma_sqr, T.maximum(layer0.sigma_sqr -learning_rate * grad_sigma_sqr_hat,\
                                             layer0.sigma_sqr/2) ))

train_model = theano.function(
    [index],
    cost,
    updates=updates,
    givens={
        x: train_set_x[index * batch_size: (index + 1) * batch_size],
        y: train_set_y[index * batch_size: (index + 1) * batch_size]
    }
)

# %%
validation_frequency = n_train_batches
best_validation_loss = numpy.inf
best_iter = 0
test_score = 0.
start_time = timeit.default_timer()

epoch = 0
done_looping = False

while (epoch < n_epochs) and (not done_looping):
    epoch = epoch + 1
    for minibatch_index in range(n_train_batches):
        iter = (epoch - 1) * n_train_batches + minibatch_index
        cost_ij = train_model(minibatch_index)
        layer0.generate_W(rng)

        if (iter + 1) % validation_frequency == 0:

            # compute zero-one loss on validation set
            validation_losses = [validate_model(i) for i
                                 in range(n_valid_batches)]
            this_validation_loss = numpy.mean(validation_losses)
            print('epoch %i, minibatch %i/%i, validation error %f %%' %
                  (epoch, minibatch_index + 1, n_train_batches,
                   this_validation_loss * 100.))

            # if we got the best validation score until now
            if this_validation_loss < best_validation_loss:
                # save best validation score and iteration number
                best_validation_loss = this_validation_loss
                best_iter = iter
                # test it on the test set
                test_losses = [
                    test_model(i)
                    for i in range(n_test_batches)
                ]
                test_score = numpy.mean(test_losses)
                print(('     epoch %i, minibatch %i/%i, test error of '
                       'best model %f %%') %
                      (epoch, minibatch_index + 1, n_train_batches,
                       test_score * 100.))
end_time = timeit.default_timer()
print('Optimization complete.')
print('Best validation score of %f %% obtained at iteration %i, '
      'with test performance %f %%' %
      (best_validation_loss * 100., best_iter + 1, test_score * 100.))
# Out:
# epoch 1, minibatch 50/50, validation error 89.300000 %
#      epoch 1, minibatch 50/50, test error of best model 89.740000 %
# epoch 2, minibatch 50/50, validation error 87.660000 %
#      epoch 2, minibatch 50/50, test error of best model 88.950000 %
# epoch 3, minibatch 50/50, validation error 93.670000 %
# epoch 4, minibatch 50/50, validation error 91.080000 %
# epoch 5, minibatch 50/50, validation error 93.320000 %
# epoch 6, minibatch 50/50, validation error 93.890000 %
# epoch 7, minibatch 50/50, validation error 90.990000 %
# epoch 8, minibatch 50/50, validation error 89.320000 %
# epoch 9, minibatch 50/50, validation error 86.800000 %
#      epoch 9, minibatch 50/50, test error of best model 88.620000 %
# epoch 10, minibatch 50/50, validation error 87.690000 %
# epoch 11, minibatch 50/50, validation error 90.180000 %
# epoch 12, minibatch 50/50, validation error 87.330000 %
# epoch 13, minibatch 50/50, validation error 88.460000 %
# epoch 14, minibatch 50/50, validation error 88.820000 %
# epoch 15, minibatch 50/50, validation error 91.830000 %
# epoch 16, minibatch 50/50, validation error 95.690000 %
# epoch 17, minibatch 50/50, validation error 82.210000 %
#      epoch 17, minibatch 50/50, test error of best model 82.530000 %
# epoch 18, minibatch 50/50, validation error 88.630000 %
# epoch 19, minibatch 50/50, validation error 88.280000 %
# epoch 20, minibatch 50/50, validation error 91.400000 %
# epoch 21, minibatch 50/50, validation error 90.310000 %
# epoch 22, minibatch 50/50, validation error 85.320000 %
# epoch 23, minibatch 50/50, validation error 88.010000 %
# epoch 24, minibatch 50/50, validation error 90.370000 %
# epoch 25, minibatch 50/50, validation error 91.320000 %
# epoch 26, minibatch 50/50, validation error 87.950000 %
# epoch 27, minibatch 50/50, validation error 93.360000 %
# epoch 28, minibatch 50/50, validation error 88.870000 %
# epoch 29, minibatch 50/50, validation error 88.100000 %
# epoch 30, minibatch 50/50, validation error 91.500000 %
# epoch 31, minibatch 50/50, validation error 92.720000 %
# epoch 32, minibatch 50/50, validation error 88.320000 %
# epoch 33, minibatch 50/50, validation error 87.460000 %
# epoch 34, minibatch 50/50, validation error 92.750000 %
# epoch 35, minibatch 50/50, validation error 86.160000 %
# epoch 36, minibatch 50/50, validation error 88.160000 %
# epoch 37, minibatch 50/50, validation error 90.030000 %
# epoch 38, minibatch 50/50, validation error 88.660000 %
# epoch 39, minibatch 50/50, validation error 92.370000 %
# epoch 40, minibatch 50/50, validation error 91.220000 %
# epoch 41, minibatch 50/50, validation error 91.470000 %
# epoch 42, minibatch 50/50, validation error 88.930000 %
# epoch 43, minibatch 50/50, validation error 90.960000 %
# epoch 44, minibatch 50/50, validation error 89.310000 %
# epoch 45, minibatch 50/50, validation error 92.530000 %
# epoch 46, minibatch 50/50, validation error 84.000000 %
# epoch 47, minibatch 50/50, validation error 86.060000 %
# epoch 48, minibatch 50/50, validation error 88.370000 %
# epoch 49, minibatch 50/50, validation error 88.990000 %
# epoch 50, minibatch 50/50, validation error 88.440000 %
# epoch 51, minibatch 50/50, validation error 90.170000 %
# epoch 52, minibatch 50/50, validation error 95.420000 %
# epoch 53, minibatch 50/50, validation error 91.250000 %
# epoch 54, minibatch 50/50, validation error 83.380000 %
# epoch 55, minibatch 50/50, validation error 90.450000 %
# epoch 56, minibatch 50/50, validation error 87.010000 %
# epoch 57, minibatch 50/50, validation error 89.020000 %
# epoch 58, minibatch 50/50, validation error 88.940000 %
# epoch 59, minibatch 50/50, validation error 88.280000 %
# epoch 60, minibatch 50/50, validation error 87.310000 %
# epoch 61, minibatch 50/50, validation error 85.230000 %
# epoch 62, minibatch 50/50, validation error 86.440000 %
# epoch 63, minibatch 50/50, validation error 89.000000 %
# epoch 64, minibatch 50/50, validation error 92.500000 %
# epoch 65, minibatch 50/50, validation error 86.620000 %
# epoch 66, minibatch 50/50, validation error 88.080000 %
# epoch 67, minibatch 50/50, validation error 75.030000 %
#      epoch 67, minibatch 50/50, test error of best model 76.550000 %
# epoch 68, minibatch 50/50, validation error 87.340000 %
# epoch 69, minibatch 50/50, validation error 87.810000 %
# epoch 70, minibatch 50/50, validation error 91.120000 %
# epoch 71, minibatch 50/50, validation error 87.430000 %
# epoch 72, minibatch 50/50, validation error 90.250000 %
# epoch 73, minibatch 50/50, validation error 91.480000 %
# epoch 74, minibatch 50/50, validation error 85.210000 %
# epoch 75, minibatch 50/50, validation error 87.160000 %
# epoch 76, minibatch 50/50, validation error 85.060000 %
# epoch 77, minibatch 50/50, validation error 84.240000 %
# epoch 78, minibatch 50/50, validation error 85.820000 %
# epoch 79, minibatch 50/50, validation error 81.500000 %
# epoch 80, minibatch 50/50, validation error 88.420000 %
# epoch 81, minibatch 50/50, validation error 83.620000 %
# epoch 82, minibatch 50/50, validation error 88.430000 %
# epoch 83, minibatch 50/50, validation error 85.150000 %
# epoch 84, minibatch 50/50, validation error 83.980000 %
# epoch 85, minibatch 50/50, validation error 88.990000 %
# epoch 86, minibatch 50/50, validation error 89.770000 %
# epoch 87, minibatch 50/50, validation error 82.850000 %
# epoch 88, minibatch 50/50, validation error 84.730000 %
# epoch 89, minibatch 50/50, validation error 85.010000 %
# epoch 90, minibatch 50/50, validation error 85.810000 %
# epoch 91, minibatch 50/50, validation error 81.500000 %
# epoch 92, minibatch 50/50, validation error 81.790000 %
# epoch 93, minibatch 50/50, validation error 86.230000 %
# epoch 94, minibatch 50/50, validation error 83.950000 %
# epoch 95, minibatch 50/50, validation error 92.590000 %
# epoch 96, minibatch 50/50, validation error 77.750000 %
# epoch 97, minibatch 50/50, validation error 89.680000 %
# epoch 98, minibatch 50/50, validation error 86.400000 %
# epoch 99, minibatch 50/50, validation error 87.480000 %
# epoch 100, minibatch 50/50, validation error 92.360000 %
# epoch 101, minibatch 50/50, validation error 78.100000 %
# epoch 102, minibatch 50/50, validation error 82.920000 %
# epoch 103, minibatch 50/50, validation error 86.200000 %
# epoch 104, minibatch 50/50, validation error 89.250000 %
# epoch 105, minibatch 50/50, validation error 87.860000 %
# epoch 106, minibatch 50/50, validation error 89.090000 %
# epoch 107, minibatch 50/50, validation error 83.610000 %
# epoch 108, minibatch 50/50, validation error 86.480000 %
# epoch 109, minibatch 50/50, validation error 86.450000 %
# epoch 110, minibatch 50/50, validation error 83.120000 %
# epoch 111, minibatch 50/50, validation error 88.240000 %
# epoch 112, minibatch 50/50, validation error 87.940000 %
# epoch 113, minibatch 50/50, validation error 84.560000 %
# epoch 114, minibatch 50/50, validation error 86.480000 %
# epoch 115, minibatch 50/50, validation error 86.120000 %
# epoch 116, minibatch 50/50, validation error 92.420000 %
# epoch 117, minibatch 50/50, validation error 85.550000 %
# epoch 118, minibatch 50/50, validation error 88.710000 %
# epoch 119, minibatch 50/50, validation error 87.220000 %
# epoch 120, minibatch 50/50, validation error 85.390000 %
# epoch 121, minibatch 50/50, validation error 87.380000 %
# epoch 122, minibatch 50/50, validation error 82.950000 %
# epoch 123, minibatch 50/50, validation error 89.840000 %
# epoch 124, minibatch 50/50, validation error 87.520000 %
# epoch 125, minibatch 50/50, validation error 86.400000 %
# epoch 126, minibatch 50/50, validation error 86.590000 %
# epoch 127, minibatch 50/50, validation error 76.150000 %
# epoch 128, minibatch 50/50, validation error 86.870000 %
# epoch 129, minibatch 50/50, validation error 85.800000 %
# epoch 130, minibatch 50/50, validation error 83.830000 %
# epoch 131, minibatch 50/50, validation error 86.640000 %
# epoch 132, minibatch 50/50, validation error 88.430000 %
# epoch 133, minibatch 50/50, validation error 84.680000 %
# epoch 134, minibatch 50/50, validation error 90.170000 %
# epoch 135, minibatch 50/50, validation error 88.510000 %
# epoch 136, minibatch 50/50, validation error 86.110000 %
# epoch 137, minibatch 50/50, validation error 90.310000 %
# epoch 138, minibatch 50/50, validation error 83.710000 %
# epoch 139, minibatch 50/50, validation error 82.700000 %
# epoch 140, minibatch 50/50, validation error 77.660000 %
# epoch 141, minibatch 50/50, validation error 85.640000 %
# epoch 142, minibatch 50/50, validation error 82.910000 %
# epoch 143, minibatch 50/50, validation error 88.400000 %
# epoch 144, minibatch 50/50, validation error 87.580000 %
# epoch 145, minibatch 50/50, validation error 85.540000 %
# epoch 146, minibatch 50/50, validation error 82.480000 %
# epoch 147, minibatch 50/50, validation error 83.490000 %
# epoch 148, minibatch 50/50, validation error 84.470000 %
# epoch 149, minibatch 50/50, validation error 75.660000 %
# epoch 150, minibatch 50/50, validation error 81.680000 %
# epoch 151, minibatch 50/50, validation error 87.720000 %
# epoch 152, minibatch 50/50, validation error 83.450000 %
# epoch 153, minibatch 50/50, validation error 91.090000 %
# epoch 154, minibatch 50/50, validation error 88.760000 %
# epoch 155, minibatch 50/50, validation error 85.120000 %
# epoch 156, minibatch 50/50, validation error 86.430000 %
# epoch 157, minibatch 50/50, validation error 87.710000 %
# epoch 158, minibatch 50/50, validation error 90.860000 %
# epoch 159, minibatch 50/50, validation error 78.840000 %
# epoch 160, minibatch 50/50, validation error 80.940000 %
# epoch 161, minibatch 50/50, validation error 90.450000 %
# epoch 162, minibatch 50/50, validation error 87.560000 %
# epoch 163, minibatch 50/50, validation error 79.530000 %
# epoch 164, minibatch 50/50, validation error 83.870000 %
# epoch 165, minibatch 50/50, validation error 88.450000 %
# epoch 166, minibatch 50/50, validation error 88.160000 %
# epoch 167, minibatch 50/50, validation error 85.360000 %
# epoch 168, minibatch 50/50, validation error 89.720000 %
# epoch 169, minibatch 50/50, validation error 78.290000 %
# epoch 170, minibatch 50/50, validation error 79.470000 %
# epoch 171, minibatch 50/50, validation error 86.540000 %
# epoch 172, minibatch 50/50, validation error 82.160000 %
# epoch 173, minibatch 50/50, validation error 85.710000 %
# epoch 174, minibatch 50/50, validation error 81.490000 %
# epoch 175, minibatch 50/50, validation error 84.210000 %
# epoch 176, minibatch 50/50, validation error 82.900000 %
# epoch 177, minibatch 50/50, validation error 85.280000 %
# epoch 178, minibatch 50/50, validation error 81.740000 %
# epoch 179, minibatch 50/50, validation error 85.180000 %
# epoch 180, minibatch 50/50, validation error 87.410000 %
# epoch 181, minibatch 50/50, validation error 90.180000 %
# epoch 182, minibatch 50/50, validation error 80.540000 %
# epoch 183, minibatch 50/50, validation error 83.290000 %
# epoch 184, minibatch 50/50, validation error 81.250000 %
# epoch 185, minibatch 50/50, validation error 85.170000 %
# epoch 186, minibatch 50/50, validation error 88.860000 %
# epoch 187, minibatch 50/50, validation error 85.020000 %
# epoch 188, minibatch 50/50, validation error 83.510000 %
# epoch 189, minibatch 50/50, validation error 80.180000 %
# epoch 190, minibatch 50/50, validation error 90.950000 %
# epoch 191, minibatch 50/50, validation error 89.090000 %
# epoch 192, minibatch 50/50, validation error 83.950000 %
# epoch 193, minibatch 50/50, validation error 83.550000 %
# epoch 194, minibatch 50/50, validation error 83.600000 %
# epoch 195, minibatch 50/50, validation error 85.560000 %

# %%
a_value = numpy.asarray([2.,3.,4.])
b_value = numpy.asarray([0.0001,9,0.8])

# %%
a = theano.shared(a_value)
b = theano.shared(b_value)
t = a/b

# %%
t.eval()
# Out:
# array([  2.00000000e+04,   3.33333333e-01,   5.00000000e+00])

# %%
a.T
# Out:
# theano.tensor.var.TensorVariable

# %%
layer0.mu.get_value()
# Out:
# array(-0.00040656287296597475)
